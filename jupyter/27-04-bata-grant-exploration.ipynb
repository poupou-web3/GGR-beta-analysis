# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns
from pathlib import Path
import os

# %%
current_dir = Path(os.getcwd())
path_to_data = os.path.join(current_dir.parent.parent, 'data')
path_to_data
# Out:
# 'c:\\Users\\DELL Admin\\Documents\\ODC\\RegenRangers\\data'

# %%
df_grants = pd.read_csv(os.path.join(path_to_data, 'Beta-applicants-projects.csv'))

# %%
df_grants.columns
# Out:
# Index(['id', 'projectNumber', 'roundId', 'status', 'amountUSD', 'votes',
#        'uniqueContributors', 'payoutAddress', 'metadata.signature',
#        'metadata.application.round', 'metadata.application.recipient',
#        'metadata.application.project.lastUpdated',
#        'metadata.application.project.createdAt',
#        'metadata.application.project.id', 'metadata.application.project.title',
#        'metadata.application.project.description',
#        'metadata.application.project.website',
#        'metadata.application.project.bannerImg',
#        'metadata.application.project.logoImg',
#        'metadata.application.project.metaPtr.protocol',
#        'metadata.application.project.metaPtr.pointer',
#        'metadata.application.project.userGithub',
#        'metadata.application.project.projectGithub',
#        'metadata.application.project.projectTwitter',
#        'metadata.application.project.credentials.twitter.@context',
#        'metadata.application.project.credentials.twitter.type',
#        'metadata.application.project.credentials.twitter.credentialSubject.id',
#        'metadata.application.project.credentials.twitter.credentialSubject.@context',
#        'metadata.application.project.credentials.twitter.credentialSubject.provider',
#        'metadata.application.project.credentials.twitter.credentialSubject.hash',
#        'metadata.application.project.credentials.twitter.issuer',
#        'metadata.application.project.credentials.twitter.issuanceDate',
#        'metadata.application.project.credentials.twitter.proof.type',
#        'metadata.application.project.credentials.twitter.proof.proofPurpose',
#        'metadata.application.project.credentials.twitter.proof.verificationMethod',
#        'metadata.application.project.credentials.twitter.proof.created',
#        'metadata.application.project.credentials.twitter.proof.jws',
#        'metadata.application.project.credentials.twitter.expirationDate',
#        'metadata.application.project.credentials.github.@context',
#        'metadata.application.project.credentials.github.type',
#        'metadata.application.project.credentials.github.credentialSubject.id',
#        'metadata.application.project.credentials.github.credentialSubject.provider',
#        'metadata.application.project.credentials.github.credentialSubject.hash',
#        'metadata.application.project.credentials.github.credentialSubject.@context',
#        'metadata.application.project.credentials.github.issuer',
#        'metadata.application.project.credentials.github.issuanceDate',
#        'metadata.application.project.credentials.github.proof.type',
#        'metadata.application.project.credentials.github.proof.proofPurpose',
#        'metadata.application.project.credentials.github.proof.verificationMethod',
#        'metadata.application.project.credentials.github.proof.created',
#        'metadata.application.project.credentials.github.proof.jws',
#        'metadata.application.project.credentials.github.expirationDate',
#        'metadata.application.answers'],
#       dtype='object')

# %%
df_grants.shape
# Out:
# (538, 53)

# %%
df_grants.head()
# Out:
#                                                   id  projectNumber
# 0  0x6aeb3ddab061203d32594b03901bf458679a66fbeab9...          355.0  \
# 1  0xdeffc2d190ddec88d06ba86e1eb09abe5a9ccb49ab1d...          174.0
# 2  0x2f4109ec6cfc94018aba83b965d4debe69381b9e86c9...          291.0
# 3  0xfea4b1dccc14b6b2d06d08ec300222497194f0f95437...          307.0
# 4  0x6240733cbc0b059b43031826f606ee20ad649694e473...          340.0
#
#                                       roundId   status  amountUSD  votes
# 0  0x12BB5bBbFE596dbc489d209299B8302c3300fa40  PENDING          0      0  \
# 1  0x12BB5bBbFE596dbc489d209299B8302c3300fa40  PENDING          0      0
# 2  0x12BB5bBbFE596dbc489d209299B8302c3300fa40  PENDING          0      0
# 3  0x12BB5bBbFE596dbc489d209299B8302c3300fa40  PENDING          0      0
# 4  0x12BB5bBbFE596dbc489d209299B8302c3300fa40  PENDING          0      0
#
#    uniqueContributors  payoutAddress
# 0                   0            NaN  \
# 1                   0            NaN
# 2                   0            NaN
# 3                   0            NaN
# 4                   0            NaN
#
#                                   metadata.signature
# 0  0x4c3db176694bdfc0f9e4a04738205d562ef31a026699...  \
# 1  0xc9f5e29fcb4db0b0c9a5909f68c162ea5d16a275f705...
# 2  0x0d5b170ceeb72eaec00a595f8270a676937acbeb67b9...
# 3  0x32a6db08937189778a4fee954a738ad534598a1fc113...
# 4  0xa8445a15122bb07f1daaad049f50dc52107540547cd5...
#
#                    metadata.application.round  ...
# 0  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  ...  \
# 1  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  ...
# 2  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  ...
# 3  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  ...
# 4  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  ...
#
#   metadata.application.project.credentials.github.credentialSubject.@context
# 0  [{'hash': 'https://schema.org/Text', 'provider...                          \
# 1  [{'hash': 'https://schema.org/Text', 'provider...
# 2  [{'hash': 'https://schema.org/Text', 'provider...
# 3  [{'hash': 'https://schema.org/Text', 'provider...
# 4  [{'hash': 'https://schema.org/Text', 'provider...
#
#   metadata.application.project.credentials.github.issuer
# 0  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...      \
# 1  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...
# 2  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...
# 3  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...
# 4  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...
#
#    metadata.application.project.credentials.github.issuanceDate
# 0                           2023-04-12T09:48:40.402Z             \
# 1                           2023-01-13T08:12:23.363Z
# 2                           2023-04-12T19:34:27.203Z
# 3                           2023-04-12T20:30:12.252Z
# 4                           2023-04-12T21:36:13.514Z
#
#   metadata.application.project.credentials.github.proof.type
# 0                               Ed25519Signature2018          \
# 1                               Ed25519Signature2018
# 2                               Ed25519Signature2018
# 3                               Ed25519Signature2018
# 4                               Ed25519Signature2018
#
#   metadata.application.project.credentials.github.proof.proofPurpose
# 0                                    assertionMethod                  \
# 1                                    assertionMethod
# 2                                    assertionMethod
# 3                                    assertionMethod
# 4                                    assertionMethod
#
#   metadata.application.project.credentials.github.proof.verificationMethod
# 0  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...                        \
# 1  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...
# 2  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...
# 3  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...
# 4  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...
#
#   metadata.application.project.credentials.github.proof.created
# 0                           2023-04-12T09:48:40.402Z             \
# 1                           2023-01-13T08:12:23.363Z
# 2                           2023-04-12T19:34:27.203Z
# 3                           2023-04-12T20:30:12.252Z
# 4                           2023-04-12T21:36:13.514Z
#
#   metadata.application.project.credentials.github.proof.jws
# 0  eyJhbGciOiJFZERTQSIsImNyaXQiOlsiYjY0Il0sImI2NC...         \
# 1  eyJhbGciOiJFZERTQSIsImNyaXQiOlsiYjY0Il0sImI2NC...
# 2  eyJhbGciOiJFZERTQSIsImNyaXQiOlsiYjY0Il0sImI2NC...
# 3  eyJhbGciOiJFZERTQSIsImNyaXQiOlsiYjY0Il0sImI2NC...
# 4  eyJhbGciOiJFZERTQSIsImNyaXQiOlsiYjY0Il0sImI2NC...
#
#   metadata.application.project.credentials.github.expirationDate
# 0                           2023-07-11T09:48:40.402Z              \
# 1                           2023-04-13T08:12:23.363Z
# 2                           2023-07-11T19:34:27.203Z
# 3                           2023-07-11T20:30:12.252Z
# 4                           2023-07-11T21:36:13.514Z
#
#                         metadata.application.answers
# 0  [{'questionId': 0, 'question': 'Email Address'...
# 1  [{'questionId': 0, 'question': 'Email Address'...
# 2  [{'questionId': 0, 'question': 'Email Address'...
# 3  [{'questionId': 0, 'question': 'Email Address'...
# 4  [{'questionId': 0, 'question': 'Email Address'...
#
# [5 rows x 53 columns]

# %%
df_grants.columns
# Out:
# Index(['id', 'projectNumber', 'roundId', 'status', 'amountUSD', 'votes',
#        'uniqueContributors', 'payoutAddress', 'metadata.signature',
#        'metadata.application.round', 'metadata.application.recipient',
#        'metadata.application.project.lastUpdated',
#        'metadata.application.project.createdAt',
#        'metadata.application.project.id', 'metadata.application.project.title',
#        'metadata.application.project.description',
#        'metadata.application.project.website',
#        'metadata.application.project.bannerImg',
#        'metadata.application.project.logoImg',
#        'metadata.application.project.metaPtr.protocol',
#        'metadata.application.project.metaPtr.pointer',
#        'metadata.application.project.userGithub',
#        'metadata.application.project.projectGithub',
#        'metadata.application.project.projectTwitter',
#        'metadata.application.project.credentials.twitter.@context',
#        'metadata.application.project.credentials.twitter.type',
#        'metadata.application.project.credentials.twitter.credentialSubject.id',
#        'metadata.application.project.credentials.twitter.credentialSubject.@context',
#        'metadata.application.project.credentials.twitter.credentialSubject.provider',
#        'metadata.application.project.credentials.twitter.credentialSubject.hash',
#        'metadata.application.project.credentials.twitter.issuer',
#        'metadata.application.project.credentials.twitter.issuanceDate',
#        'metadata.application.project.credentials.twitter.proof.type',
#        'metadata.application.project.credentials.twitter.proof.proofPurpose',
#        'metadata.application.project.credentials.twitter.proof.verificationMethod',
#        'metadata.application.project.credentials.twitter.proof.created',
#        'metadata.application.project.credentials.twitter.proof.jws',
#        'metadata.application.project.credentials.twitter.expirationDate',
#        'metadata.application.project.credentials.github.@context',
#        'metadata.application.project.credentials.github.type',
#        'metadata.application.project.credentials.github.credentialSubject.id',
#        'metadata.application.project.credentials.github.credentialSubject.provider',
#        'metadata.application.project.credentials.github.credentialSubject.hash',
#        'metadata.application.project.credentials.github.credentialSubject.@context',
#        'metadata.application.project.credentials.github.issuer',
#        'metadata.application.project.credentials.github.issuanceDate',
#        'metadata.application.project.credentials.github.proof.type',
#        'metadata.application.project.credentials.github.proof.proofPurpose',
#        'metadata.application.project.credentials.github.proof.verificationMethod',
#        'metadata.application.project.credentials.github.proof.created',
#        'metadata.application.project.credentials.github.proof.jws',
#        'metadata.application.project.credentials.github.expirationDate',
#        'metadata.application.answers'],
#       dtype='object')

# %%
df_grants['metadata.application.project.title'].unique()
# Out:
# array(['DAOstar', 'datalatte ☕️ ', 'Aurellion', 'beaconcha.in',
#        'xLog - Write. Own. Earn.',
#        'Punk Domains - Modular Web3 Names Protocol',
#        'IDriss - A more usable web3 for everyone',
#        'Using ZK for game optimization in Dark Forest',
#        'Web3 OSS Libraries by DePay', 'Lenster', 'Lenstube',
#        'HarbergerToken - A Decentraliazed Infra for Sustainable Funding of Open Source Proj.',
#        'Quest Chains', 'Revoke.cash - Helping you stay safe in web3',
#        'eth.limo', 'TrueBlocks and the Unchained Index', 'ADOR',
#        'Shivarthu Democracy', 'JediSwap', 'Starksheet', 'neume',
#        'DefiLab.xyz', 'Umbra', 'DefiLlama', 'Sovr', 'Flexible Voting',
#        'Geo Web', 'Voting Contracts', 'Rouge Ticket',
#        'word block - Your reference notebook', 'Rave Names', '0xDeadList',
#        'ROBOTS.TXT', 'The Science Commons Initiative', 'Loanshark',
#        'W3Space(previously W3.work)', 'Decentrifi', 'Candide Wallet',
#        'ENSRedirect', 'Zk- Block | Tools for Zk & Web3 Dapps', 'Giveth',
#        'FundPG', 'Wireshape - Open Blockchain for Product Data', 'POAPin',
#        'Buckets', 'Praise', 'ethstaker.tax', 'Seedle',
#        'Uniswap V3 Calculator & Simulator', 'Backpack',
#        'Fusion – Open Source Web3 Icon Set',
#        'Lume Web - Your Open & Private Internet', 'Zeron Protocol',
#        'HODL Totals', 'Better - Github issues automated MicroGrants',
#        'Decert.me', 'useWeb3 - Web3 Developer platform', 'Chaineye',
#        'Pairwise: Tinder UX for web3 community signaling', 'EVMcrispr',
#        'viaPrize', 'Inverter Network - Fund and build in web 3 with ease',
#        'ENS Wayback Machine', 'tProof', 'BountyX', '1Hive Gardens',
#        'FiatConnect', 'DecentrAgora', 'The Slipstream', 'Governator',
#        'ChaintoolDAO', 'OmniBTC', 'Detask', 'Fstar', 'DeCartography',
#        'zenbit.eth', 'Uniswap.fish',
#        'DOM Money – wallet for everyday expenses',
#        'Pin Save: decentralized Pinterest', 'Test', 'Carbonable',
#        'Stackly', 'ITU Blockchain', 'Sadaiv', 'Thunder Chat',
#        'Taho - Open Source and Community Owned Wallet', 'Glo Dollar',
#        'Eppie: Web3 native email and identity manager',
#        'Arm0ry Playground', 'Pluser | Web3 Account', 'Commons Stack',
#        'Changeth - private verifiable petitions',
#        'Decentralizing Journalism to Restore Public Trust', 'Zuzu',
#        'fatcat.money', 'Primordium', 'Project LION: Building Leo',
#        'Stake Together', 'BrightID 🔆 Universal Proof of Uniqueness',
#        'pRoots:   genomic data protocol on plasmid for bridging synbio and web3 for desci ecosystem',
#        'Spect', 'MetaDock', 'Via | Cross-chain router',
#        'Leto | Transfer crypto', 'OP Medicine', 'aikipay', '1W3',
#        'crypto-jobs-crawler', 'signless', 'White Hat DAO', 'rotki',
#        'Ape Framework', 'Ethereum on ARM',
#        'Rhino Review - Ethereum Staking Journal', 'wagmi',
#        'Blockscout - Decentralized, Open-source Block Explorer Built for L1s, L2s and All Chains',
#        'Chainlist', 'EthStaker', 'Ethereum Staking Guides by CoinCashew',
#        'Creative Organization DAO', 'Lighthouse by Sigma Prime',
#        'Voltaire ERC-4337 Bundler', 'ZKode',
#        'NiceNode: Run a node — just press start', 'Kakarot zkEVM',
#        'DAppNode', 'Protocol Guild',
#        'TKN.eth | The Onchain Token Database', 'Blobscan',
#        'Everyname—Name Resolver as a Service', 'Etheriot Games',
#        'Stereum - Ethereum Node Installer & Manager', 'Gator Labs',
#        'Topia', 'ethers.js', 'Dapplet', 'L2BEAT', 'Dippi', 'Otterscan',
#        'PADO', 'ExplorerX', 'Prettier Solidity', 'Innovaz',
#        'Zero Knowledge Podcast', '4EVERLAND', '404 DAO', 'ZeroPool',
#        'zkBob', 'chokepoint', 'Sprintcheckout', 'EZKL',
#        'Switch Electric: Maxwell', 'Trustless zkMafia',
#        'Proof of Innocence', 'Metagov', 'Cryptocurrency Jobs',
#        'Gravity DAO', 'ETH Daily',
#        'Somer Esat Ethereum Staking Guides (Ubuntu)', 'LensTags',
#        'Bankless Brasil DAO', 'KultureCity F THE NEVERS',
#        'Proof of Integrity', 'Fractal Visions',
#        'NatyShi Web3 & Tokenomics in Spanish', 'ETH Kipu',
#        'Built Different', 'FIRST 721 CLUB', 'The Follow Black Hare',
#        'Boring Security',
#        'Social Impact - Through Culturally Rich Web3 Gaming & Entertainment',
#        'Book - Women of DeSci, ReFi, ReSci & DeFi',
#        'Burning Sissy Valley', 'Zaliban the game', 'Cryptoversidad',
#        'ResearchHub Foundation - SciCon 2023', 'FACTLAND DAO',
#        "Archimedes' Lever", 'DeFi & Web3 Developer Roadmap',
#        'iCrypto Media', 'zkpod.ai', 'Dot.alert()',
#        'DuaCrypto: The Premier Ethereum YouTube Channel',
#        'Crypto Fundraising', 'Njombe Innovation Academy',
#        'Web3TalentFair', 'L2 Planet', 'DeSci Africa',
#        'The Bees Marketing', 'Trusted Seed', 'Phoenix Cover',
#        'Factland DAO: Bet on Factual Disputes and Convene Random Sample Juries to Issue Verdicts and Rewards',
#        'Empowering Ethereum Tegucigalpa', 'Ethereum Dominicana',
#        'WTF Academy', 'Blocktrend（區塊勢）',
#        'Impact DAOs Research + Podcast + Book : Impact DAO Media Season 2 ',
#        'DAO Governance Collective', 'Web3Afrika',
#        'Give the Gift of Education to Children in Poverty',
#        'Nowhere Publishing (NFT books with open access content)',
#        'DHK dao', 'Decentralized Library', 'ATX DAO', 'Dream DAO',
#        'Week in Ethereum News', 'BanklessDAO Projects',
#        'IberoAm: promoting and supporting iberoamerican impact projects',
#        'Actocracy', 'DAO Times', 'Machina',
#        'PlannerDAO On-Chain Certification Process', 'Natives in Tech',
#        'Ethereum Colombia DAO', '500K by 2030', 'Advantage Blockchain',
#        'Kernel', 'Greenpill Podcast', 'DeFinomics Labs', 'cp0x',
#        '40acres DAO',
#        'Impact Academy: making impact knowledge accessible',
#        'CruzoCards - Multi-chain NFT marketplace & Web3 AI-powered platform for digital emotions',
#        'Daolize', 'Prānah : Reading Redefined!', 'Defi Wars',
#        'RightfulShare: Putting digital currency in the hands of South Africans to access their rightful share of the digital economy.',
#        'CryptoCurious- Puerto Rico Blockchain Trade Association',
#        'OpenGuitar',
#        'Learning Data Science on the Ethereum Blockchain with @omnianalytics',
#        'Buidl Guidl', 'Women Biz Education Program', 'Andino',
#        'Web3Domains.com',
#        'Crypto Altruism – Accessible Web3 Education for Nonprofits and Changemakers',
#        'Mujeres en Crypto', 'HER Tribe', 'DAOVOZ', 'DigiCult',
#        'POAPathon', 'Blu3 Global', 'Culture Blocks', 'Metopia',
#        'Today in DeFi', '登链社区(Upchain)',
#        'Chinwags: Focused Retreats for Web3 Builders',
#        'Regens Unite: Building bridges between web3 and local regens',
#        'Upgrading Ethereum Book', 'Proof of Volunteer Protocol (POVP)',
#        'RemittDAO', 'EmprendeDAO',
#        '0xEdu - The first decentralized K-12 curriculum and school',
#        'HER LATAM', 'Liker Land ',
#        'Mechanism Institute: Democratizing Cryptoeconomics',
#        'EUCI - European Crypto Initiative - educating policy makers on decentralization',
#        'CriptoCuriosas', 'CreatorDAO', 'Meet Crypto',
#        "Let's demystify crypto and web3 in Africa", 'H.E.R. DAO ',
#        'Impact DAO Course + IRL/Online Events: Educating Changemakers on How To Impact DAO',
#        'Infinite Garden Library', 'DWeb Fellowship Fund',
#        'Blacks on Blockchain', 'SEED Latam', 'ZachXBT', 'EthCartagena',
#        'Web3 Educational Programming for Underserved Communities - Presented by Superchief Gallery NFT',
#        'Playgotchi', 'Redemption Land', 'L2 en Español',
#        'Ethereum Bolivia', 'Bonding Curves Research Group', 'MakeWater',
#        'Blockchain at the School: Web3 Education for Brazil’s Public School Students',
#        'B<>rder/ess',
#        'Zbra DAO - Unleashing purpose driven entrepreneurs',
#        'CryptoConexión', 'ETH Tricolor ETH Ecuador', 'ScrumDAO',
#        'WAGMI LATAM', 'Ethereum Mexico',
#        'forthepeoplexyz: good music, good causes, sounds good',
#        'ENS DAO Newsletter', 'Russia 3.0', 'LOA Labs : ReFi by South',
#        'Bu Zhi DAO', '"JPGs Against Humanity" Documentary Series', 'DAZE',
#        'Cryptonikas', 'ai4news', 'ProXify DAO',
#        'Decentalized Science NYC (DeSciNYC)', 'The Neptune Project',
#        'ARTXV', 'Carbon Anti-Theft', 'Cosmos for Humanity | C4H',
#        'Training rural farmers on regenerative agriculture and planting fruit trees in schools, churches and health centers',
#        'LunCo: complex systems design', 'Climecheck',
#        'WarmOFF - CO₂ removal project', 'Litter Token',
#        'Hazel - Mobile Game That Fights Climate Change',
#        'Fundación Tucultura ', 'ECOHUELLAS', 'Pulso Verde',
#        'Test Grant: Save the Unicorns', 'DexGrid Community Microgrids',
#        'Fightersgang',
#        'Barichara Regeneration Fund – Prototyping a Bioregional Regenerative Economy',
#        'The Angry Teenagers - democratising investment in reforestation projects',
#        'UniZ', 'de_plan ostrom', 'The Solar Foundation', 'R3WILD',
#        '7Energy - Energy Communities without Banks',
#        'MesoReefDAO - Regenerating Reef Conservation with DeSci Web3 tools',
#        'Mirage Arts Community - Putting into action or collective crafting and landscaping skills ',
#        'Solarpunk nomads: tracing nomadic routes with the first two public goods adventure vehicles',
#        'CCC: photojournalism expeditions on the field to document Climate Change',
#        '$Earth - Solarpunk Dao', 'Heating with Compute Power',
#        'KOKO DAO saving forests in Colombia',
#        'Kula कुल Regenerative Commons', 'Astral Protocol',
#        'Green Digital Guardians',
#        'GainForest: A Planetary Computer for ReFi powered by DeSci and AI',
#        'Endangered Tokens: Endangered Trees as ReFi Biodiversity Assets ',
#        'Green Arks Foundation', 'Ranna: Filmmakers for Climate',
#        'Knysna Alien Busters', 'Block2030', 'TaterDAO', 'Bye Bye Plastic',
#        'Climate Attestation Protocol', 'Web3beach', 'Bloom Network',
#        'Coffee Impact Collective',
#        'The Wildlife Movement Institute: An Open-Source Tracking Community',
#        'Avano', 'BETTER', 'Atlantis', 'Younergy Crypto',
#        'Shamba DMRV and Ecological Data Oracle.', 'ECORISE',
#        'DeFood: Decentralized Food Security Network (DFSN)', 'regrò ',
#        'Digital Gaia: A Science-Based Co-Pilot to Defeat Moloch and Regenerate the Planet',
#        'Bloomeria', 'Nawonmesh - Regenerating Buxar (Bihar, India)',
#        'Myseelia 🍄', 'SISU Living Portals', 'Urbanika', 'oxygenchain',
#        'Kokonut Network; Building an Eco-Friendly Perpetual Fund',
#        'AgroforestDAO', 'Realtime Climate Data Extension (RealClime)',
#        'Treegens - The Most Transparent & Rewarding Tree Planting',
#        'DLTEO (Orbuculum)', 'Ekonavi', 'Crowdmuse', 'dMeter',
#        'AYOWECCA UGANDA:       Training rural farmers & indigenous communities on regenerative agriculture and planting fruit trees in schools, health centers & churches',
#        'Silvi', 'Climate & Nature Hyperstructure | .basin',
#        'Simbiotica | The source for impact insights on-chain.',
#        'WaterDAO', 'KUMO - Money Backed By Nature', 'KNS Domains',
#        'Tree Tales: Play to Plant', 'Plants And Pillars', 'Mirror',
#        'Re-Public',
#        'Online Course: The Meta-Crisis - What it is and what you can do about it',
#        'Iris', 'Incubator for addressing the metacrisis',
#        'proving ground', 'Credible Commitment Mechanism ', 'Forby.io',
#        'Civol Earth',
#        'diosdao.xyz by Mycelia : Indigenous Public Goods for Global Coordination',
#        'Gifting Wisdom Conversation Research',
#        'Upala 🤖 Price-of-forgery digital identity',
#        'One click sybil scores', 'SOFAMON', 'Datadex',
#        'Abundance Protocol', 'Tokenomics Design Space',
#        'Towards an Industry Standard Python Library for Token Engineering',
#        'Token Engineering Knowledge Commons', 'Burn-and-mint tokenomics',
#        'Oxcart Applied Research', 'dAgora', 'Share',
#        'Fileverse – because Notion & Gsuite are centralised and expensive',
#        'Twittens.xyz', 'Plebbit', 'Gameland', 'Nextme',
#        'Lens Clubs: the social multi-sig',
#        'Fileverse – sovereign collaboration to replace Notion & Gsuite',
#        'MantleSwap', 'Salaries Science', 'Replicare', 'PlantGang',
#        'Health X Change', 'Agua AI', 'Crowd Funded Cures',
#        'Active Blockference: an Open Source Package for Cognitive Modeling in Web3',
#        'Just-DNA-Seq', 'AxonDAO', 'Fractal Flows', 'Seeds of Science',
#        'Zubar', 'DeSci LATAM', 'inTheory Research Funding', 'Algovera',
#        'DeScicommons.org: This time we will fix science',
#        'Esteroids - a community .eth websites search engine', 'ENS Data',
#        'Heavens Tools', '3bra.com 🦓 Your Colorful Web3 Profile',
#        'Faster API for resolving ENS names and avatars for web3 projects',
#        'ENS Doc', 'Gitcoin China Ecosystem Development'], dtype=object)

# %%
df_all_allo = pd.read_csv(os.path.join(path_to_data, 'all-allo.csv'))

# %%
df_all_allo.head()
# Out:
#                                                   id  projectNumber
# 0  0x6ec5ee60255a3593d5b35b46f53b02adef97afb5ecf9...              0  \
# 1  0xa0affa31521afe084aee15c3ff5570c600b014cae2a9...              1
# 2  0x5d8c43ef40b6294bee31db1875e1a4535775044899dd...              2
# 3  0x128a79c5f52d33bc49f5677dd0fcd695e44f22916b92...              3
# 4  0x6d6e8fc20ac24fdb4b3efea919528f41eb0261a65c30...              4
#
#                                              metaPtr
# 0  bafkreicj2mfcotvh4tcg2yxivox3udf3nn2ac73jx4unt...  \
# 1  bafkreici2x2ttp2ln2x2gagkooq3i4q3npvdbl3d6aevi...
# 2  bafkreibuxaoktceabvxug76wqv7jxcxrmlxgfent3cdsd...
# 3  bafkreih2o2iyhnuo54fwglpi5vqd5zwlzcsoavfgaqqqj...
# 4  bafkreibopxik34xkruefa7yliw3icifwjv56xio327htt...
#
#                                            owners
# 0  ['0xA4ca1b15fE81F57cb2d3f686c7B13309906cd37B']  \
# 1  ['0x6faaD3C23Ba7F04db0b54B87C185cE4fb2676B60']
# 2  ['0xc2E2B715d9e302947Ec7e312fd2384b5a1296099']
# 3  ['0x112E372bb5EC17c1ea6b1d679EA72aFBD2A94404']
# 4  ['0xE559e959b891b14eB5A9DdE45C61b1aEb0b6DF4B']
#
#                                       metadata.title
# 0                                              Pharo  \
# 1                                        CryptoStats
# 2                       Gitcoin Grants Matching Pool
# 3                                           Chaineye
# 4  Empowering communities and young generation wi...
#
#                                 metadata.description
# 0  A web3 automated market maker for wisdom of cr...  \
# 1  One neutral source of truth for crypto metrics...
# 2  This is the official matching pool fund for al...
# 3  ChainEye aims to build the world leading free ...
# 4  CRYTO AWARENESS & EDUCATION\n To reach mass-sc...
#
#                  metadata.website           metadata.projectTwitter
# 0              https://pharo.tech                          PharoACM  \
# 1  https://cryptostats.community/  https://twitter.com/CryptoStats_
# 2              https://gitcoin.co                           gitcoin
# 3          https://Chaineye.tools                          biteyecn
# 4      https://ayoweccauganda.org                               NaN
#
#   metadata.userGithub metadata.projectGithub  ...
# 0       codenamejason               PharoACM  ...  \
# 1                 NaN                    NaN  ...
# 2              kweiss              gitcoinco  ...
# 3           DeFiTeddy                DeFiEye  ...
# 4                 NaN                    NaN  ...
#
#   metadata.credentials.twitter.credentialSubject.provider
# 0                          ClearTextTwitter#PharoACM       \
# 1                                                NaN
# 2                           ClearTextTwitter#gitcoin
# 3                          ClearTextTwitter#BiteyeCN
# 4                                                NaN
#
#                  metadata.credentials.twitter.issuer
# 0  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...  \
# 1                                                NaN
# 2  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...
# 3  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...
# 4                                                NaN
#
#   metadata.credentials.twitter.issuanceDate
# 0                  2022-11-29T16:13:27.820Z  \
# 1                                       NaN
# 2                  2022-12-02T18:00:45.224Z
# 3                  2023-04-15T14:45:43.079Z
# 4                                       NaN
#
#   metadata.credentials.twitter.proof.type
# 0                    Ed25519Signature2018  \
# 1                                     NaN
# 2                    Ed25519Signature2018
# 3                    Ed25519Signature2018
# 4                                     NaN
#
#   metadata.credentials.twitter.proof.proofPurpose
# 0                                 assertionMethod  \
# 1                                             NaN
# 2                                 assertionMethod
# 3                                 assertionMethod
# 4                                             NaN
#
#   metadata.credentials.twitter.proof.verificationMethod
# 0  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...     \
# 1                                                NaN
# 2  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...
# 3  did:key:z6MkghvGHLobLEdj1bgRLhS4LPGJAvbMA1tn2z...
# 4                                                NaN
#
#   metadata.credentials.twitter.proof.created
# 0                   2022-11-29T16:13:27.820Z  \
# 1                                        NaN
# 2                   2022-12-02T18:00:45.224Z
# 3                   2023-04-15T14:45:43.079Z
# 4                                        NaN
#
#               metadata.credentials.twitter.proof.jws
# 0  eyJhbGciOiJFZERTQSIsImNyaXQiOlsiYjY0Il0sImI2NC...  \
# 1                                                NaN
# 2  eyJhbGciOiJFZERTQSIsImNyaXQiOlsiYjY0Il0sImI2NC...
# 3  eyJhbGciOiJFZERTQSIsImNyaXQiOlsiYjY0Il0sImI2NC...
# 4                                                NaN
#
#   metadata.credentials.twitter.expirationDate             metadata.createdAt
# 0                    2023-02-27T16:13:27.820Z  1970-01-01 00:00:00.000000000
# 1                                         NaN  2022-12-01 18:04:50.731000064
# 2                    2023-03-02T18:00:45.224Z  2022-12-02 18:01:39.035000064
# 3                    2023-07-14T14:45:43.079Z  2022-12-04 01:18:54.937999872
# 4                                         NaN  2022-12-05 14:10:07.805999872
#
# [5 rows x 41 columns]

# %%
df_all_allo.id[0]
# Out:
# '0x6ec5ee60255a3593d5b35b46f53b02adef97afb5ecf996aa04673ac7a1a3ba57'
